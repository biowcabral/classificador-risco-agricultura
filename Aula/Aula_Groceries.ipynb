# %% [markdown]
# # Fase (1): Importação do conjunto de dados e transformação em matriz binária

# %%
#!pip install mlxtend

# %%
import pandas as pd

# %%
df = pd.read_csv('groceries.csv', sep=';', header=None)

# %% [markdown]
# df

# %%
df.shape
# Out:
# (9835, 1)

# %% [markdown]
# ### Primeiro, precisamos transformar o dataframe em listas com as strings que representam cada item adquirido, em cada registro

# %%
lista_compras = list()

for i in df.values.tolist():
    lista_compras.append(i[0].split(','))

# %%
lista_compras[:5]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product']]

# %% [markdown]
# ### Agora podemos aplicar o método TransactionEncoder() para transformar em matriz binária

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()

# %%
lista_encoded = te.fit_transform(lista_compras, sparse=False)

# %%
te.columns_[:10]
# Out:
# ['Instant food products',
#  'UHT-milk',
#  'abrasive cleaner',
#  'artif. sweetener',
#  'baby cosmetics',
#  'baby food',
#  'bags',
#  'baking powder',
#  'bathroom cleaner',
#  'beef']

# %%
df_compras = pd.DataFrame(data=lista_encoded, columns=te.columns_)

# %%
df_compras.head()
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics  baby food   bags  baking powder  bathroom cleaner   beef  \
# 0           False      False  False          False             False  False
# 1           False      False  False          False             False  False
# 2           False      False  False          False             False  False
# 3           False      False  False          False             False  False
# 4           False      False  False          False             False  False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False       False   False     False
# 1       False       False    True     False
# 2       False        True   False     False
# 3       False       False    True     False
# 4       False        True   False     False
#
# [5 rows x 169 columns]

# %%
df_compras.shape
# Out:
# (9835, 169)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(25, 15))
sns.heatmap(df_compras, cmap='mako')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Fase (2): Geração de itens frequentes com Apriori e FP-Growth (min_support=0.02)

# %%
from mlxtend.frequent_patterns import apriori, fpgrowth

# %%
# Apriori
ap_itemsets = apriori(df_compras, min_support=0.02, use_colnames=True)

# %%
ap_itemsets
# Out:
#       support                                         itemsets
# 0    0.033452                                       (UHT-milk)
# 1    0.052466                                           (beef)
# 2    0.033249                                        (berries)
# 3    0.026029                                      (beverages)
# 4    0.080529                                   (bottled beer)
# ..        ...                                              ...
# 117  0.032232                 (whipped/sour cream, whole milk)
# 118  0.020742                     (whipped/sour cream, yogurt)
# 119  0.056024                             (whole milk, yogurt)
# 120  0.023183  (root vegetables, other vegetables, whole milk)
# 121  0.022267           (other vegetables, whole milk, yogurt)
#
# [122 rows x 2 columns]

# %%
ap_itemsets.sort_values(by='support', ascending=False).tail(10)
# Out:
#       support                           itemsets
# 94   0.021047                     (pastry, soda)
# 105  0.021047  (root vegetables, tropical fruit)
# 93   0.020946               (pastry, rolls/buns)
# 112  0.020844             (tropical fruit, soda)
# 118  0.020742       (whipped/sour cream, yogurt)
# 75   0.020539          (whole milk, frankfurter)
# 60   0.020437         (whole milk, bottled beer)
# 76   0.020437    (whole milk, frozen vegetables)
# 96   0.020437        (pip fruit, tropical fruit)
# 67   0.020031         (other vegetables, butter)

# %%
# FP-Growth
fp_itemsets = fpgrowth(df_compras, min_support=0.02, use_colnames=True)

# %%
fp_itemsets
# Out:
#       support                           itemsets
# 0    0.082766                     (citrus fruit)
# 1    0.058566                        (margarine)
# 2    0.139502                           (yogurt)
# 3    0.104931                   (tropical fruit)
# 4    0.058058                           (coffee)
# ..        ...                                ...
# 117  0.022166                 (whole milk, pork)
# 118  0.021657           (other vegetables, pork)
# 119  0.029995        (whole milk, domestic eggs)
# 120  0.022267  (other vegetables, domestic eggs)
# 121  0.020437    (whole milk, frozen vegetables)
#
# [122 rows x 2 columns]

# %%
fp_itemsets.sort_values(by='support', ascending=False).tail(10)
# Out:
#       support                           itemsets
# 51   0.021047                      (chewing gum)
# 72   0.021047  (root vegetables, tropical fruit)
# 99   0.020946               (pastry, rolls/buns)
# 73   0.020844             (tropical fruit, soda)
# 116  0.020742       (whipped/sour cream, yogurt)
# 93   0.020539          (whole milk, frankfurter)
# 82   0.020437         (whole milk, bottled beer)
# 75   0.020437        (pip fruit, tropical fruit)
# 121  0.020437    (whole milk, frozen vegetables)
# 79   0.020031         (other vegetables, butter)

# %% [markdown]
# # Fase (3): Criação das regras de associação (utilizando apenas o ap_itemsets)

# %%
from mlxtend.frequent_patterns import association_rules

# %%
regras = association_rules(ap_itemsets, metric="confidence", min_threshold=0.3)

# %%
regras.sort_values(by='confidence', ascending=False)
# Out:
#                             antecedents         consequents  \
# 35           (other vegetables, yogurt)        (whole milk)
# 4                              (butter)        (whole milk)
# 7                                (curd)        (whole milk)
# 32  (root vegetables, other vegetables)        (whole milk)
# 33        (root vegetables, whole milk)  (other vegetables)
# 9                       (domestic eggs)        (whole milk)
# 30                 (whipped/sour cream)        (whole milk)
# 27                    (root vegetables)        (whole milk)
# 17                    (root vegetables)  (other vegetables)
# 11                  (frozen vegetables)        (whole milk)
# 13                          (margarine)        (whole milk)
# 0                                (beef)        (whole milk)
# 29                     (tropical fruit)        (whole milk)
# 19                 (whipped/sour cream)  (other vegetables)
# 31                             (yogurt)        (whole milk)
# 23                          (pip fruit)        (whole milk)
# 36                 (whole milk, yogurt)  (other vegetables)
# 2                         (brown bread)        (whole milk)
# 20                   (other vegetables)        (whole milk)
# 24                               (pork)        (whole milk)
# 16                               (pork)  (other vegetables)
# 22                             (pastry)        (whole milk)
# 6                        (citrus fruit)        (whole milk)
# 12              (fruit/vegetable juice)        (whole milk)
# 3                              (butter)  (other vegetables)
# 8                       (domestic eggs)  (other vegetables)
# 5                        (citrus fruit)  (other vegetables)
# 10                        (frankfurter)        (whole milk)
# 15                          (pip fruit)  (other vegetables)
# 14                         (newspapers)        (whole milk)
# 18                     (tropical fruit)  (other vegetables)
# 25                            (sausage)        (rolls/buns)
# 28                            (sausage)        (whole milk)
# 21                             (yogurt)  (other vegetables)
# 1                       (bottled water)        (whole milk)
# 34       (whole milk, other vegetables)   (root vegetables)
# 26                         (rolls/buns)        (whole milk)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 35            0.043416            0.255516  0.022267    0.512881  2.007235
# 4             0.055414            0.255516  0.027555    0.497248  1.946053
# 7             0.053279            0.255516  0.026131    0.490458  1.919481
# 32            0.047382            0.255516  0.023183    0.489270  1.914833
# 33            0.048907            0.193493  0.023183    0.474012  2.449770
# 9             0.063447            0.255516  0.029995    0.472756  1.850203
# 30            0.071683            0.255516  0.032232    0.449645  1.759754
# 27            0.108998            0.255516  0.048907    0.448694  1.756031
# 17            0.108998            0.193493  0.047382    0.434701  2.246605
# 11            0.048094            0.255516  0.020437    0.424947  1.663094
# 13            0.058566            0.255516  0.024199    0.413194  1.617098
# 0             0.052466            0.255516  0.021251    0.405039  1.585180
# 29            0.104931            0.255516  0.042298    0.403101  1.577595
# 19            0.071683            0.193493  0.028876    0.402837  2.081924
# 31            0.139502            0.255516  0.056024    0.401603  1.571735
# 23            0.075648            0.255516  0.030097    0.397849  1.557043
# 36            0.056024            0.193493  0.022267    0.397459  2.054131
# 2             0.064870            0.255516  0.025216    0.388715  1.521293
# 20            0.193493            0.255516  0.074835    0.386758  1.513634
# 24            0.057651            0.255516  0.022166    0.384480  1.504719
# 16            0.057651            0.193493  0.021657    0.375661  1.941476
# 22            0.088968            0.255516  0.033249    0.373714  1.462587
# 6             0.082766            0.255516  0.030503    0.368550  1.442377
# 12            0.072293            0.255516  0.026640    0.368495  1.442160
# 3             0.055414            0.193493  0.020031    0.361468  1.868122
# 8             0.063447            0.193493  0.022267    0.350962  1.813824
# 5             0.082766            0.193493  0.028876    0.348894  1.803140
# 10            0.058973            0.255516  0.020539    0.348276  1.363029
# 15            0.075648            0.193493  0.026131    0.345430  1.785237
# 14            0.079817            0.255516  0.027351    0.342675  1.341110
# 18            0.104931            0.193493  0.035892    0.342054  1.767790
# 25            0.093950            0.183935  0.030605    0.325758  1.771048
# 28            0.093950            0.255516  0.029893    0.318182  1.245252
# 21            0.139502            0.193493  0.043416    0.311224  1.608457
# 1             0.110524            0.255516  0.034367    0.310948  1.216940
# 34            0.074835            0.108998  0.023183    0.309783  2.842082
# 26            0.183935            0.255516  0.056634    0.307905  1.205032
#
#     leverage  conviction
# 35  0.011174    1.528340
# 4   0.013395    1.480817
# 7   0.012517    1.461085
# 32  0.011076    1.457687
# 33  0.013719    1.533320
# 9   0.013783    1.412030
# 30  0.013916    1.352735
# 27  0.021056    1.350401
# 17  0.026291    1.426693
# 11  0.008149    1.294636
# 13  0.009235    1.268706
# 0   0.007845    1.251315
# 29  0.015486    1.247252
# 19  0.015006    1.350565
# 31  0.020379    1.244132
# 23  0.010767    1.236375
# 36  0.011427    1.338511
# 2   0.008641    1.217899
# 20  0.025394    1.214013
# 24  0.007435    1.209520
# 16  0.010502    1.291779
# 22  0.010516    1.188729
# 6   0.009355    1.179008
# 12  0.008168    1.178904
# 3   0.009308    1.263065
# 8   0.009991    1.242619
# 5   0.012862    1.238674
# 10  0.005470    1.142330
# 15  0.011494    1.232118
# 14  0.006957    1.132597
# 18  0.015589    1.225796
# 25  0.013324    1.210344
# 28  0.005887    1.091910
# 21  0.016424    1.170929
# 1   0.006126    1.080446
# 34  0.015026    1.290900
# 26  0.009636    1.075696
